# %%
# !nvidia-smi
# Out:
# Wed May  5 08:15:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ../content/drive/MyDrive/github/Pokemon-GAN
# Out:
# /content/drive/MyDrive/github/Pokemon-GAN

# %%
import os
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Self Attention Layer

# %%
class Self_Attention(nn.Module):
    def __init__(self, in_dim=100, image_size=256):
        super(Self_Attention, self).__init__()

        self.query_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(in_channels=in_dim, out_channels=in_dim, kernel_size=1)

        self.softmax = nn.Softmax(dim=-2)
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):
        X = x

        proj_query = self.query_conv(X).view(X.shape[0], -1, X.shape[2]*X.shape[3])
        proj_query = proj_query.permute(0,2,1)
        proj_key = self.key_conv(X).view(X.shape[0], -1, X.shape[2]*X.shape[3])

        S = torch.bmm(proj_query, proj_key)

        attention_map_T = self.softmax(S)
        attention_map = attention_map_T.permute(0,2,1)

        proj_value = self.value_conv(X).view(X.shape[0], -1, X.shape[2]*X.shape[3])
        o = torch.bmm(proj_value, attention_map.permute(0,2,1))

        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        out = x + self.gamma*o
        return out, attention_map

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self, feature_dim=100, image_size=264):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.utils.spectral_norm(nn.ConvTranspose2d(feature_dim, image_size*8, kernel_size=4,stride=1)),
            nn.BatchNorm2d(image_size*8),
            nn.ReLU(inplace=True)
        )

        self.layer2 = nn.Sequential(
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*8, image_size*4, kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size*4),
            nn.ReLU(inplace=True)
        )

        self.layer3 = nn.Sequential(
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*4, image_size*2, kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size*2),
            nn.ReLU(inplace=True)
        )

        self.self_attention1 = Self_Attention(in_dim=image_size*2)

        self.layer4 = nn.Sequential(
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*2, image_size, kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True)
        )

        self.self_attention2 = Self_Attention(in_dim=image_size)

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 3, kernel_size=4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, feature):
        conv1_out = self.layer1(feature)
        conv2_out = self.layer2(conv1_out)
        conv3_out = self.layer3(conv2_out)
        attention1_out, attention_map1 = self.self_attention1(conv3_out)
        conv4_out = self.layer4(attention1_out)
        attention2_out, attention_map2 = self.self_attention2(conv4_out)
        out = self.last(attention2_out)

        return out, [attention_map1, attention_map2] , [conv1_out,conv2_out,conv3_out,attention1_out,conv4_out,attention2_out]

# %%
# Check Generator
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(feature_dim=100, image_size=64)

input_z = torch.randn(1, 100)

input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

fake_images, attention_maps, layers_outputs = G(input_z)

fig = plt.figure(figsize=(10,6))
for i, layer in enumerate(layers_outputs):
    img_activation = layer[0][0].detach().numpy()
    plt.subplot(2,4,i+1)
    plt.imshow(img_activation)
img_transformed = fake_images[0][0].detach().numpy()
plt.subplot(2,4,7)
plt.imshow(img_transformed)
plt.show()
print(input_z.shape)
for output in layers_outputs:
    print(output.shape)
print(fake_images.shape)
# Out:
# torch.Size([1, 100, 1, 1])
# torch.Size([1, 512, 4, 4])
# torch.Size([1, 256, 8, 8])
# torch.Size([1, 128, 16, 16])
# torch.Size([1, 128, 16, 16])
# torch.Size([1, 64, 32, 32])
# torch.Size([1, 64, 32, 32])
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):

    def __init__(self, feature_dim=100, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.utils.spectral_norm(nn.Conv2d(3, image_size, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer2 = nn.Sequential(
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        
        self.self_attention1 = Self_Attention(in_dim=image_size*4)

        self.layer4 = nn.Sequential(
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8, kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))

        self.self_attention2 = Self_Attention(in_dim=image_size*8)

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, feature):
        conv1_out = self.layer1(feature)
        conv2_out = self.layer2(conv1_out)
        conv3_out = self.layer3(conv2_out)
        attention1_out, attention_map1 = self.self_attention1(conv3_out)
        conv4_out = self.layer4(attention1_out)
        attention2_out, attention_map2 = self.self_attention2(conv4_out)
        out = self.last(attention2_out)

        return out, [attention_map1, attention_map2] , [conv1_out,conv2_out,conv3_out,attention1_out,conv4_out,attention2_out]

# %%
# Discriminator Check
D = Discriminator(feature_dim=100, image_size=64)

input_z = torch.randn(1, 100)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

d_out, attention_map1, attention_map2 = D(fake_images)

print(nn.Sigmoid()(d_out))
# Out:
# tensor([[[[0.5062]]]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# # Data Loader

# %%
def make_datapath_list():

    train_img_list = list()

    for i in range(898):
        index = i+1
        if index//10 == 0:
            index_str = f"00{index}"
        elif index/10 < 10:
            index_str = f"0{index}"
        else:
            index_str = str(index)
        img_path = f"./Pokemon_zukan/img{index_str}.png"
        train_img_list.append(img_path)

    return train_img_list

class ImageTransform():

    def __init__(self, size):
        self.data_transform = transforms.Compose([
            transforms.Resize((size,size)),
            transforms.ToTensor(),
        ])

    def __call__(self, img):
        return self.data_transform(img)

class GAN_Img_Dataset(data.Dataset):
    
    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, index):

        img_path = self.file_list[index]
        img = Image.open(img_path).convert('RGB')

        img_transformed = self.transform(img)

        return img_transformed

# %%
train_img_list=make_datapath_list()

size = 64
train_dataset = GAN_Img_Dataset(file_list=train_img_list, transform=ImageTransform(size))

batch_size = 32

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

batch_iterator = iter(train_dataloader)
imges = next(batch_iterator)
print(imges.size())
# Out:
# torch.Size([32, 3, 64, 64])

# %%
def train_model(G, D, dataloader, num_epochs, model_name=None):

    if model_name != None:
      if not os.path.isdir(f"./saved_model/{model_name}"):
        os.makedirs(f"./saved_model/{model_name}")
        os.makedirs(f"./saved_model/{model_name}/CPU/Generator")
        os.makedirs(f"./saved_model/{model_name}/CPU/Discriminator")
        os.makedirs(f"./saved_model/{model_name}/GPU/Generator")
        os.makedirs(f"./saved_model/{model_name}/GPU/Discriminator")

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)

    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    feature_dim = 100
    mini_batch_size = 32

    G.to(device)
    D.to(device)

    G.train()
    D.train()

    torch.backends.cudnn.benchmark = True

    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    iteration = 1
    G_logs = []
    D_logs = []

    for epoch in range(num_epochs):

        t_epoch_start = time.time()
        epoch_g_loss = 0.0
        epoch_d_loss = 0.0

        print('-----------------')
        print(f"Epoch{epoch}/{num_epochs}")
        print('-----------------')
        print(' (train) ')

        for images in dataloader:
            # If batch size is 0, BatchNormLayer dont work 
            if images.size()[0] == 1:
                continue
            
            images = images.to(device)
            # make label
            mini_batch_size = images.size()[0]

            #######################
            # Discriminator train #
            #######################
            d_out_real, _, _ = D(images)
            # make fake images & predict
            input_feature = torch.randn(mini_batch_size, feature_dim).to(device)
            input_feature = input_feature.view(input_feature.size(0), input_feature.size(1), 1, 1)
            fake_images, _, _ = G(input_feature)
            d_out_fake, _, _ = D(fake_images)
            # calculate loss
            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            d_loss = d_loss_real + d_loss_fake
            # back propagation
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            ###################
            # Generator train #
            ###################
            # make fake imagaes & predict
            input_feature = torch.randn(mini_batch_size, feature_dim).to(device)
            input_feature = input_feature.view(input_feature.size(0), input_feature.size(1), 1, 1)
            fake_images, _, _ = G(input_feature)
            d_out_fake, _, _ = D(fake_images)
            # calculate loss
            g_loss = - d_out_fake.mean()
            # back propagation
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()
            
            #############
            # Recording #
            #############
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        t_epoch_finish = time.time()
        print('-------------')
        print(f"epoch {epoch} || Epoch_D_Loss:{epoch_d_loss/batch_size:.4f} || Epoch_G_Loss:{epoch_g_loss/batch_size:.4f}")
        print(f"timer: {t_epoch_finish - t_epoch_start:.4f}")
        t_epoch_start = time.time()
        G_logs.append(epoch_g_loss/batch_size)
        D_logs.append(epoch_d_loss/batch_size)

        if model_name != None and epoch%20 == 0:
          model_path =  f"./saved_model/{model_name}"
          file_name = f"{epoch}.pth"
          torch.save(G.state_dict(), f"{model_path}/GPU/Generator/{file_name}")
          torch.save(D.state_dict(), f"{model_path}/GPU/Discriminator/{file_name}")
          torch.save(G.to('cpu').state_dict(), f"{model_path}/CPU/Generator/{file_name}")
          torch.save(D.to('cpu').state_dict(), f"{model_path}/CPU/Discriminator/{file_name}")
          G.to(device)
          D.to(device)

    if model_name != None:
          model_path =  f"./saved_model/{model_name}"
          file_name = f"{num_epochs}.pth"
          torch.save(G.state_dict(), f"{model_path}/GPU/Generator/{file_name}")
          torch.save(D.state_dict(), f"{model_path}/GPU/Discriminator/{file_name}")
          torch.save(G.to('cpu').state_dict(), f"{model_path}/CPU/Generator/{file_name}")
          torch.save(D.to('cpu').state_dict(), f"{model_path}/CPU/Discriminator/{file_name}")
          G.to(device)
          D.to(device)
    return G, D

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

G.apply(weights_init)
D.apply(weights_init)

print("Network initialize completed")
# Out:
# Network initialize completed

# %% [markdown]
# # Training

# %%
num_epochs = 500
G_update, D_update = train_model(G, D, dataloader=train_dataloader, num_epochs=num_epochs,model_name="SAGAN")
# Out:
# Using device: cuda:0
# -----------------
# Epoch0/500
# -----------------
#  (train)
# -------------
# epoch 0 || Epoch_D_Loss:0.7737 || Epoch_G_Loss:1.1086
# timer: 178.4826
# -----------------
# Epoch1/500
# -----------------
#  (train)
# -------------
# epoch 1 || Epoch_D_Loss:0.7957 || Epoch_G_Loss:0.4774
# timer: 9.1722
# -----------------
# Epoch2/500
# -----------------
#  (train)
# -------------
# epoch 2 || Epoch_D_Loss:0.4082 || Epoch_G_Loss:1.0628
# timer: 9.2065
# -----------------
# Epoch3/500
# -----------------
#  (train)
# -------------
# epoch 3 || Epoch_D_Loss:0.4959 || Epoch_G_Loss:1.3191
# timer: 9.0244
# -----------------
# Epoch4/500
# -----------------
#  (train)
# -------------
# epoch 4 || Epoch_D_Loss:0.7366 || Epoch_G_Loss:1.1132
# timer: 8.9832
# -----------------
# Epoch5/500
# -----------------
#  (train)
# -------------
# epoch 5 || Epoch_D_Loss:0.8688 || Epoch_G_Loss:0.9988
# timer: 9.0351
# -----------------
# Epoch6/500
# -----------------
#  (train)
# -------------
# epoch 6 || Epoch_D_Loss:1.1494 || Epoch_G_Loss:0.7237
# timer: 9.0535
# -----------------
# Epoch7/500
# -----------------
#  (train)
# -------------
# epoch 7 || Epoch_D_Loss:0.9076 || Epoch_G_Loss:0.9395
# timer: 9.1346
# -----------------
# Epoch8/500
# -----------------
#  (train)
# -------------
# epoch 8 || Epoch_D_Loss:1.0948 || Epoch_G_Loss:0.8760
# timer: 9.0816
# -----------------
# Epoch9/500
# -----------------
#  (train)
# -------------
# epoch 9 || Epoch_D_Loss:1.0679 || Epoch_G_Loss:1.0269
# timer: 9.0809
# -----------------
# Epoch10/500
# -----------------
#  (train)
# -------------
# epoch 10 || Epoch_D_Loss:1.1420 || Epoch_G_Loss:0.8358
# timer: 9.2269
# -----------------
# Epoch11/500
# -----------------
#  (train)
# -------------
# epoch 11 || Epoch_D_Loss:0.8442 || Epoch_G_Loss:1.2147
# timer: 9.0978
# -----------------
# Epoch12/500
# -----------------
#  (train)
# -------------
# epoch 12 || Epoch_D_Loss:0.9517 || Epoch_G_Loss:0.9340
# timer: 9.1369
# -----------------
# Epoch13/500
# -----------------
#  (train)
# -------------
# epoch 13 || Epoch_D_Loss:0.7668 || Epoch_G_Loss:1.2355
# timer: 9.0153
# -----------------
# Epoch14/500
# -----------------
#  (train)
# -------------
# epoch 14 || Epoch_D_Loss:0.8619 || Epoch_G_Loss:1.1866
# timer: 9.1142
# -----------------
# Epoch15/500
# -----------------
#  (train)
# -------------
# epoch 15 || Epoch_D_Loss:1.1261 || Epoch_G_Loss:0.8912
# timer: 9.1353
# -----------------
# Epoch16/500
# -----------------
#  (train)
# -------------
# epoch 16 || Epoch_D_Loss:0.9079 || Epoch_G_Loss:1.0809
# timer: 9.2482
# -----------------
# Epoch17/500
# -----------------
#  (train)
# -------------
# epoch 17 || Epoch_D_Loss:1.1104 || Epoch_G_Loss:1.1639
# timer: 9.1916
# -----------------
# Epoch18/500
# -----------------
#  (train)
# -------------
# epoch 18 || Epoch_D_Loss:0.9561 || Epoch_G_Loss:1.0949
# timer: 9.3238
# -----------------
# Epoch19/500
# -----------------
#  (train)
# -------------
# epoch 19 || Epoch_D_Loss:1.1145 || Epoch_G_Loss:1.2534
# timer: 9.3861
# -----------------
# Epoch20/500
# -----------------
#  (train)
# -------------
# epoch 20 || Epoch_D_Loss:1.1750 || Epoch_G_Loss:1.0685
# timer: 9.4214
# -----------------
# Epoch21/500
# -----------------
#  (train)
# -------------
# epoch 21 || Epoch_D_Loss:1.1922 || Epoch_G_Loss:0.9114
# timer: 9.5841
# -----------------
# Epoch22/500
# -----------------
#  (train)
# -------------
# epoch 22 || Epoch_D_Loss:1.1830 || Epoch_G_Loss:1.0772
# timer: 9.4141
# -----------------
# Epoch23/500
# -----------------
#  (train)
# -------------
# epoch 23 || Epoch_D_Loss:1.0402 || Epoch_G_Loss:1.0265
# timer: 9.5196
# -----------------
# Epoch24/500
# -----------------
#  (train)
# -------------
# epoch 24 || Epoch_D_Loss:1.0373 || Epoch_G_Loss:1.0376
# timer: 9.4495
# -----------------
# Epoch25/500
# -----------------
#  (train)
# -------------
# epoch 25 || Epoch_D_Loss:1.1938 || Epoch_G_Loss:0.9579
# timer: 9.2350
# -----------------
# Epoch26/500
# -----------------
#  (train)
# -------------
# epoch 26 || Epoch_D_Loss:1.2291 || Epoch_G_Loss:0.9804
# timer: 9.3605
# -----------------
# Epoch27/500
# -----------------
#  (train)
# -------------
# epoch 27 || Epoch_D_Loss:1.0118 || Epoch_G_Loss:0.9893
# timer: 9.3894
# -----------------
# Epoch28/500
# -----------------
#  (train)
# -------------
# epoch 28 || Epoch_D_Loss:1.0736 || Epoch_G_Loss:1.1466
# timer: 9.2706
# -----------------
# Epoch29/500
# -----------------
#  (train)
# -------------
# epoch 29 || Epoch_D_Loss:1.1673 || Epoch_G_Loss:0.9681
# timer: 9.3556
# -----------------
# Epoch30/500
# -----------------
#  (train)
# -------------
# epoch 30 || Epoch_D_Loss:1.3026 || Epoch_G_Loss:0.9051
# timer: 9.3660
# -----------------
# Epoch31/500
# -----------------
#  (train)
# -------------
# epoch 31 || Epoch_D_Loss:0.9803 || Epoch_G_Loss:1.0873
# timer: 9.3404
# -----------------
# Epoch32/500
# -----------------
#  (train)
# -------------
# epoch 32 || Epoch_D_Loss:1.2956 || Epoch_G_Loss:0.8553
# timer: 9.2589
# -----------------
# Epoch33/500
# -----------------
#  (train)
# -------------
# epoch 33 || Epoch_D_Loss:1.2804 || Epoch_G_Loss:0.8432
# timer: 9.4161
# -----------------
# Epoch34/500
# -----------------
#  (train)
# -------------
# epoch 34 || Epoch_D_Loss:1.3306 || Epoch_G_Loss:0.7697
# timer: 9.3658
# -----------------
# Epoch35/500
# -----------------
#  (train)
# -------------
# epoch 35 || Epoch_D_Loss:1.2238 || Epoch_G_Loss:0.9771
# timer: 9.3023
# -----------------
# Epoch36/500
# -----------------
#  (train)
# -------------
# epoch 36 || Epoch_D_Loss:1.0446 || Epoch_G_Loss:1.0954
# timer: 9.3603
# -----------------
# Epoch37/500
# -----------------
#  (train)
# -------------
# epoch 37 || Epoch_D_Loss:1.2191 || Epoch_G_Loss:0.9423
# timer: 9.5334
# -----------------
# Epoch38/500
# -----------------
#  (train)
# -------------
# epoch 38 || Epoch_D_Loss:1.1716 || Epoch_G_Loss:0.9387
# timer: 9.4532
# -----------------
# Epoch39/500
# -----------------
#  (train)
# -------------
# epoch 39 || Epoch_D_Loss:1.0687 || Epoch_G_Loss:0.9226
# timer: 9.4600
# -----------------
# Epoch40/500
# -----------------
#  (train)
# -------------
# epoch 40 || Epoch_D_Loss:1.1923 || Epoch_G_Loss:0.9866
# timer: 9.4384
# -----------------
# Epoch41/500
# -----------------
#  (train)
# -------------
# epoch 41 || Epoch_D_Loss:1.1396 || Epoch_G_Loss:1.0012
# timer: 9.5344
# -----------------
# Epoch42/500
# -----------------
#  (train)
# -------------
# epoch 42 || Epoch_D_Loss:1.0672 || Epoch_G_Loss:1.0952
# timer: 9.4708
# -----------------
# Epoch43/500
# -----------------
#  (train)
# -------------
# epoch 43 || Epoch_D_Loss:1.0911 || Epoch_G_Loss:1.0686
# timer: 9.6244
# -----------------
# Epoch44/500
# -----------------
#  (train)
# -------------
# epoch 44 || Epoch_D_Loss:1.2261 || Epoch_G_Loss:0.9361
# timer: 9.5350
# -----------------
# Epoch45/500
# -----------------
#  (train)
# -------------
# epoch 45 || Epoch_D_Loss:0.8810 || Epoch_G_Loss:1.2664
# timer: 9.3855
# -----------------
# Epoch46/500
# -----------------
#  (train)
# -------------
# epoch 46 || Epoch_D_Loss:1.1981 || Epoch_G_Loss:0.9200
# timer: 9.4619
# -----------------
# Epoch47/500
# -----------------
#  (train)
# -------------
# epoch 47 || Epoch_D_Loss:1.0569 || Epoch_G_Loss:1.0982
# timer: 9.3484
# -----------------
# Epoch48/500
# -----------------
#  (train)
# -------------
# epoch 48 || Epoch_D_Loss:1.1637 || Epoch_G_Loss:0.9400
# timer: 9.4507
# -----------------
# Epoch49/500
# -----------------
#  (train)
# -------------
# epoch 49 || Epoch_D_Loss:1.1647 || Epoch_G_Loss:0.9091
# timer: 9.4461
# -----------------
# Epoch50/500
# -----------------
#  (train)
# -------------
# epoch 50 || Epoch_D_Loss:1.0836 || Epoch_G_Loss:0.9937
# timer: 9.5041
# -----------------
# Epoch51/500
# -----------------
#  (train)
# -------------
# epoch 51 || Epoch_D_Loss:1.0816 || Epoch_G_Loss:0.9329
# timer: 9.4236
# -----------------
# Epoch52/500
# -----------------
#  (train)
# -------------
# epoch 52 || Epoch_D_Loss:1.0077 || Epoch_G_Loss:1.0388
# timer: 9.4875
# -----------------
# Epoch53/500
# -----------------
#  (train)
# -------------
# epoch 53 || Epoch_D_Loss:1.0483 || Epoch_G_Loss:0.9664
# timer: 9.5261
# -----------------
# Epoch54/500
# -----------------
#  (train)
# -------------
# epoch 54 || Epoch_D_Loss:0.8902 || Epoch_G_Loss:1.2448
# timer: 9.4701
# -----------------
# Epoch55/500
# -----------------
#  (train)
# -------------
# epoch 55 || Epoch_D_Loss:0.7787 || Epoch_G_Loss:1.2869
# timer: 9.4122
# -----------------
# Epoch56/500
# -----------------
#  (train)
# -------------
# epoch 56 || Epoch_D_Loss:0.7975 || Epoch_G_Loss:1.3285
# timer: 9.4123
# -----------------
# Epoch57/500
# -----------------
#  (train)
# -------------
# epoch 57 || Epoch_D_Loss:1.0110 || Epoch_G_Loss:1.1337
# timer: 9.4308
# -----------------
# Epoch58/500
# -----------------
#  (train)
# -------------
# epoch 58 || Epoch_D_Loss:1.1787 || Epoch_G_Loss:1.0592
# timer: 9.4472
# -----------------
# Epoch59/500
# -----------------
#  (train)
# -------------
# epoch 59 || Epoch_D_Loss:1.2552 || Epoch_G_Loss:1.1008
# timer: 9.4740
# -----------------
# Epoch60/500
# -----------------
#  (train)
# -------------
# epoch 60 || Epoch_D_Loss:0.9440 || Epoch_G_Loss:1.0560
# timer: 9.4606
# -----------------
# Epoch61/500
# -----------------
#  (train)
# -------------
# epoch 61 || Epoch_D_Loss:1.0337 || Epoch_G_Loss:1.0428
# timer: 9.5005
# -----------------
# Epoch62/500
# -----------------
#  (train)
# -------------
# epoch 62 || Epoch_D_Loss:1.0240 || Epoch_G_Loss:1.2365
# timer: 9.3683
# -----------------
# Epoch63/500
# -----------------
#  (train)
# -------------
# epoch 63 || Epoch_D_Loss:0.8719 || Epoch_G_Loss:1.1083
# timer: 9.3621
# -----------------
# Epoch64/500
# -----------------
#  (train)
# -------------
# epoch 64 || Epoch_D_Loss:0.9763 || Epoch_G_Loss:1.1994
# timer: 9.3976
# -----------------
# Epoch65/500
# -----------------
#  (train)
# -------------
# epoch 65 || Epoch_D_Loss:1.1965 || Epoch_G_Loss:0.9854
# timer: 9.5362
# -----------------
# Epoch66/500
# -----------------
#  (train)
# -------------
# epoch 66 || Epoch_D_Loss:0.9694 || Epoch_G_Loss:1.0833
# timer: 9.4289
# -----------------
# Epoch67/500
# -----------------
#  (train)
# -------------
# epoch 67 || Epoch_D_Loss:0.7845 || Epoch_G_Loss:1.0763
# timer: 9.3770
# -----------------
# Epoch68/500
# -----------------
#  (train)
# -------------
# epoch 68 || Epoch_D_Loss:1.1410 || Epoch_G_Loss:1.0702
# timer: 9.5164
# -----------------
# Epoch69/500
# -----------------
#  (train)
# -------------
# epoch 69 || Epoch_D_Loss:0.8999 || Epoch_G_Loss:1.1606
# timer: 9.4024
# -----------------
# Epoch70/500
# -----------------
#  (train)
# -------------
# epoch 70 || Epoch_D_Loss:1.0242 || Epoch_G_Loss:1.1476
# timer: 9.4336
# -----------------
# Epoch71/500
# -----------------
#  (train)
# -------------
# epoch 71 || Epoch_D_Loss:0.9435 || Epoch_G_Loss:1.0501
# timer: 9.4648
# -----------------
# Epoch72/500
# -----------------
#  (train)
# -------------
# epoch 72 || Epoch_D_Loss:1.1883 || Epoch_G_Loss:0.9349
# timer: 9.4674
# -----------------
# Epoch73/500
# -----------------
#  (train)
# -------------
# epoch 73 || Epoch_D_Loss:1.0725 || Epoch_G_Loss:0.9352
# timer: 9.4689
# -----------------
# Epoch74/500
# -----------------
#  (train)
# -------------
# epoch 74 || Epoch_D_Loss:1.0195 || Epoch_G_Loss:0.8502
# timer: 9.3838
# -----------------
# Epoch75/500
# -----------------
#  (train)
# -------------
# epoch 75 || Epoch_D_Loss:1.1255 || Epoch_G_Loss:0.7354
# timer: 9.5491
# -----------------
# Epoch76/500
# -----------------
#  (train)
# -------------
# epoch 76 || Epoch_D_Loss:1.1440 || Epoch_G_Loss:0.6819
# timer: 9.4603
# -----------------
# Epoch77/500
# -----------------
#  (train)
# -------------
# epoch 77 || Epoch_D_Loss:1.1665 || Epoch_G_Loss:0.6573
# timer: 9.3691
# -----------------
# Epoch78/500
# -----------------
#  (train)
# -------------
# epoch 78 || Epoch_D_Loss:1.1818 || Epoch_G_Loss:0.6933
# timer: 9.3900
# -----------------
# Epoch79/500
# -----------------
#  (train)
# -------------
# epoch 79 || Epoch_D_Loss:1.1556 || Epoch_G_Loss:0.7119
# timer: 9.4696
# -----------------
# Epoch80/500
# -----------------
#  (train)
# -------------
# epoch 80 || Epoch_D_Loss:1.1276 || Epoch_G_Loss:0.7865
# timer: 9.3407
# -----------------
# Epoch81/500
# -----------------
#  (train)
# -------------
# epoch 81 || Epoch_D_Loss:1.1589 || Epoch_G_Loss:0.7937
# timer: 9.4590
# -----------------
# Epoch82/500
# -----------------
#  (train)
# -------------
# epoch 82 || Epoch_D_Loss:1.1960 || Epoch_G_Loss:0.7040
# timer: 9.4494
# -----------------
# Epoch83/500
# -----------------
#  (train)
# -------------
# epoch 83 || Epoch_D_Loss:1.1721 || Epoch_G_Loss:0.6459
# timer: 9.3790
# -----------------
# Epoch84/500
# -----------------
#  (train)
# -------------
# epoch 84 || Epoch_D_Loss:1.1400 || Epoch_G_Loss:0.6474
# timer: 9.5353
# -----------------
# Epoch85/500
# -----------------
#  (train)
# -------------
# epoch 85 || Epoch_D_Loss:1.1013 || Epoch_G_Loss:0.7997
# timer: 9.4271
# -----------------
# Epoch86/500
# -----------------
#  (train)
# -------------
# epoch 86 || Epoch_D_Loss:1.1602 || Epoch_G_Loss:0.6466
# timer: 9.3884
# -----------------
# Epoch87/500
# -----------------
#  (train)
# -------------
# epoch 87 || Epoch_D_Loss:1.1709 || Epoch_G_Loss:0.6923
# timer: 9.4900
# -----------------
# Epoch88/500
# -----------------
#  (train)
# -------------
# epoch 88 || Epoch_D_Loss:1.1773 || Epoch_G_Loss:0.6705
# timer: 9.4049
# -----------------
# Epoch89/500
# -----------------
#  (train)
# -------------
# epoch 89 || Epoch_D_Loss:1.1271 || Epoch_G_Loss:0.6265
# timer: 9.4140
# -----------------
# Epoch90/500
# -----------------
#  (train)
# -------------
# epoch 90 || Epoch_D_Loss:1.1313 || Epoch_G_Loss:0.6663
# timer: 9.4272
# -----------------
# Epoch91/500
# -----------------
#  (train)
# -------------
# epoch 91 || Epoch_D_Loss:1.1782 || Epoch_G_Loss:0.6581
# timer: 9.3748
# -----------------
# Epoch92/500
# -----------------
#  (train)
# -------------
# epoch 92 || Epoch_D_Loss:1.1011 || Epoch_G_Loss:0.7452
# timer: 9.4329
# -----------------
# Epoch93/500
# -----------------
#  (train)
# -------------
# epoch 93 || Epoch_D_Loss:1.2199 || Epoch_G_Loss:0.5835
# timer: 9.3469
# -----------------
# Epoch94/500
# -----------------
#  (train)
# -------------
# epoch 94 || Epoch_D_Loss:1.1162 || Epoch_G_Loss:0.7102
# timer: 9.4519
# -----------------
# Epoch95/500
# -----------------
#  (train)
# -------------
# epoch 95 || Epoch_D_Loss:1.1991 || Epoch_G_Loss:0.6056
# timer: 9.4434
# -----------------
# Epoch96/500
# -----------------
#  (train)
# -------------
# epoch 96 || Epoch_D_Loss:1.1341 || Epoch_G_Loss:0.7034
# timer: 9.6031
# -----------------
# Epoch97/500
# -----------------
#  (train)
# -------------
# epoch 97 || Epoch_D_Loss:1.1638 || Epoch_G_Loss:0.7046
# timer: 9.5000
# -----------------
# Epoch98/500
# -----------------
#  (train)
# -------------
# epoch 98 || Epoch_D_Loss:1.2154 || Epoch_G_Loss:0.5949
# timer: 9.4449
# -----------------
# Epoch99/500
# -----------------
#  (train)
# -------------
# epoch 99 || Epoch_D_Loss:1.2189 || Epoch_G_Loss:0.6742
# timer: 9.4131
# -----------------
# Epoch100/500
# -----------------
#  (train)
# -------------
# epoch 100 || Epoch_D_Loss:1.1596 || Epoch_G_Loss:0.6583
# timer: 9.4569
# -----------------
# Epoch101/500
# -----------------
#  (train)
# -------------
# epoch 101 || Epoch_D_Loss:1.1347 || Epoch_G_Loss:0.7141
# timer: 9.5354
# -----------------
# Epoch102/500
# -----------------
#  (train)
# -------------
# epoch 102 || Epoch_D_Loss:1.2207 || Epoch_G_Loss:0.6238
# timer: 9.3364
# -----------------
# Epoch103/500
# -----------------
#  (train)
# -------------
# epoch 103 || Epoch_D_Loss:1.1751 || Epoch_G_Loss:0.6235
# timer: 9.4509
# -----------------
# Epoch104/500
# -----------------
#  (train)
# -------------
# epoch 104 || Epoch_D_Loss:1.1546 || Epoch_G_Loss:0.6056
# timer: 9.3891
# -----------------
# Epoch105/500
# -----------------
#  (train)
# -------------
# epoch 105 || Epoch_D_Loss:1.1689 || Epoch_G_Loss:0.6200
# timer: 9.3656
# -----------------
# Epoch106/500
# -----------------
#  (train)
# -------------
# epoch 106 || Epoch_D_Loss:1.1663 || Epoch_G_Loss:0.6378
# timer: 9.5093
# -----------------
# Epoch107/500
# -----------------
#  (train)
# -------------
# epoch 107 || Epoch_D_Loss:1.2043 || Epoch_G_Loss:0.6847
# timer: 9.3682
# -----------------
# Epoch108/500
# -----------------
#  (train)
# -------------
# epoch 108 || Epoch_D_Loss:1.1088 || Epoch_G_Loss:0.6331
# timer: 9.4384
# -----------------
# Epoch109/500
# -----------------
#  (train)
# -------------
# epoch 109 || Epoch_D_Loss:1.1795 || Epoch_G_Loss:0.6379
# timer: 9.4010
# -----------------
# Epoch110/500
# -----------------
#  (train)
# -------------
# epoch 110 || Epoch_D_Loss:1.1526 || Epoch_G_Loss:0.6474
# timer: 9.4612
# -----------------
# Epoch111/500
# -----------------
#  (train)
# -------------
# epoch 111 || Epoch_D_Loss:1.1483 || Epoch_G_Loss:0.6112
# timer: 9.3192
# -----------------
# Epoch112/500
# -----------------
#  (train)
# -------------
# epoch 112 || Epoch_D_Loss:1.1532 || Epoch_G_Loss:0.5573
# timer: 9.3646
# -----------------
# Epoch113/500
# -----------------
#  (train)
# -------------
# epoch 113 || Epoch_D_Loss:1.1404 || Epoch_G_Loss:0.6391
# timer: 9.3471
# -----------------
# Epoch114/500
# -----------------
#  (train)
# -------------
# epoch 114 || Epoch_D_Loss:1.1319 || Epoch_G_Loss:0.6279
# timer: 9.3471
# -----------------
# Epoch115/500
# -----------------
#  (train)
# -------------
# epoch 115 || Epoch_D_Loss:1.1512 || Epoch_G_Loss:0.7164
# timer: 9.3512
# -----------------
# Epoch116/500
# -----------------
#  (train)
# -------------
# epoch 116 || Epoch_D_Loss:1.0829 || Epoch_G_Loss:0.7326
# timer: 9.5550
# -----------------
# Epoch117/500
# -----------------
#  (train)
# -------------
# epoch 117 || Epoch_D_Loss:1.1406 || Epoch_G_Loss:0.6391
# timer: 9.4203
# -----------------
# Epoch118/500
# -----------------
#  (train)
# -------------
# epoch 118 || Epoch_D_Loss:1.1128 || Epoch_G_Loss:0.7115
# timer: 9.3883
# -----------------
# Epoch119/500
# -----------------
#  (train)
# -------------
# epoch 119 || Epoch_D_Loss:1.0461 || Epoch_G_Loss:0.6372
# timer: 9.4051
# -----------------
# Epoch120/500
# -----------------
#  (train)
# -------------
# epoch 120 || Epoch_D_Loss:1.0621 || Epoch_G_Loss:0.7288
# timer: 9.3916
# -----------------
# Epoch121/500
# -----------------
#  (train)
# -------------
# epoch 121 || Epoch_D_Loss:1.0438 || Epoch_G_Loss:0.7183
# timer: 9.3947
# -----------------
# Epoch122/500
# -----------------
#  (train)
# -------------
# epoch 122 || Epoch_D_Loss:0.9897 || Epoch_G_Loss:0.7700
# timer: 9.2463
# -----------------
# Epoch123/500
# -----------------
#  (train)
# -------------
# epoch 123 || Epoch_D_Loss:1.0288 || Epoch_G_Loss:0.7198
# timer: 9.2025
# -----------------
# Epoch124/500
# -----------------
#  (train)
# -------------
# epoch 124 || Epoch_D_Loss:1.0202 || Epoch_G_Loss:0.7869
# timer: 9.2763
# -----------------
# Epoch125/500
# -----------------
#  (train)
# -------------
# epoch 125 || Epoch_D_Loss:1.0220 || Epoch_G_Loss:0.7402
# timer: 9.2106
# -----------------
# Epoch126/500
# -----------------
#  (train)
# -------------
# epoch 126 || Epoch_D_Loss:1.0272 || Epoch_G_Loss:0.7860
# timer: 9.2757
# -----------------
# Epoch127/500
# -----------------
#  (train)
# -------------
# epoch 127 || Epoch_D_Loss:0.9728 || Epoch_G_Loss:0.7646
# timer: 9.2967
# -----------------
# Epoch128/500
# -----------------
#  (train)
# -------------
# epoch 128 || Epoch_D_Loss:0.9230 || Epoch_G_Loss:0.8116
# timer: 9.2298
# -----------------
# Epoch129/500
# -----------------
#  (train)
# -------------
# epoch 129 || Epoch_D_Loss:1.0284 || Epoch_G_Loss:0.7970
# timer: 9.2283
# -----------------
# Epoch130/500
# -----------------
#  (train)
# -------------
# epoch 130 || Epoch_D_Loss:1.0473 || Epoch_G_Loss:0.6606
# timer: 9.2198
# -----------------
# Epoch131/500
# -----------------
#  (train)
# -------------
# epoch 131 || Epoch_D_Loss:1.0331 || Epoch_G_Loss:0.7236
# timer: 9.3060
# -----------------
# Epoch132/500
# -----------------
#  (train)
# -------------
# epoch 132 || Epoch_D_Loss:0.9947 || Epoch_G_Loss:0.7360
# timer: 9.3756
# -----------------
# Epoch133/500
# -----------------
#  (train)
# -------------
# epoch 133 || Epoch_D_Loss:0.9709 || Epoch_G_Loss:0.7798
# timer: 9.4142
# -----------------
# Epoch134/500
# -----------------
#  (train)
# -------------
# epoch 134 || Epoch_D_Loss:0.9285 || Epoch_G_Loss:0.8157
# timer: 9.5071
# -----------------
# Epoch135/500
# -----------------
#  (train)
# -------------
# epoch 135 || Epoch_D_Loss:0.9090 || Epoch_G_Loss:0.8937
# timer: 9.8668
# -----------------
# Epoch136/500
# -----------------
#  (train)
# -------------
# epoch 136 || Epoch_D_Loss:0.9414 || Epoch_G_Loss:0.8684
# timer: 9.5918
# -----------------
# Epoch137/500
# -----------------
#  (train)
# -------------
# epoch 137 || Epoch_D_Loss:0.9115 || Epoch_G_Loss:0.7944
# timer: 9.6763
# -----------------
# Epoch138/500
# -----------------
#  (train)
# -------------
# epoch 138 || Epoch_D_Loss:1.0174 || Epoch_G_Loss:0.8474
# timer: 9.5657
# -----------------
# Epoch139/500
# -----------------
#  (train)
# -------------
# epoch 139 || Epoch_D_Loss:0.9368 || Epoch_G_Loss:0.8268
# timer: 9.4411
# -----------------
# Epoch140/500
# -----------------
#  (train)
# -------------
# epoch 140 || Epoch_D_Loss:0.9087 || Epoch_G_Loss:0.8756
# timer: 9.3591
# -----------------
# Epoch141/500
# -----------------
#  (train)
# -------------
# epoch 141 || Epoch_D_Loss:0.9480 || Epoch_G_Loss:0.8677
# timer: 9.6029
# -----------------
# Epoch142/500
# -----------------
#  (train)
# -------------
# epoch 142 || Epoch_D_Loss:0.8701 || Epoch_G_Loss:0.8593
# timer: 9.3817
# -----------------
# Epoch143/500
# -----------------
#  (train)
# -------------
# epoch 143 || Epoch_D_Loss:0.8949 || Epoch_G_Loss:0.8711
# timer: 9.2984
# -----------------
# Epoch144/500
# -----------------
#  (train)
# -------------
# epoch 144 || Epoch_D_Loss:0.8870 || Epoch_G_Loss:0.8469
# timer: 9.3618
# -----------------
# Epoch145/500
# -----------------
#  (train)
# -------------
# epoch 145 || Epoch_D_Loss:0.8878 || Epoch_G_Loss:0.9821
# timer: 9.3683
# -----------------
# Epoch146/500
# -----------------
#  (train)
# -------------
# epoch 146 || Epoch_D_Loss:0.7749 || Epoch_G_Loss:0.9750
# timer: 9.3241
# -----------------
# Epoch147/500
# -----------------
#  (train)
# -------------
# epoch 147 || Epoch_D_Loss:0.8202 || Epoch_G_Loss:1.0022
# timer: 9.3893
# -----------------
# Epoch148/500
# -----------------
#  (train)
# -------------
# epoch 148 || Epoch_D_Loss:0.8558 || Epoch_G_Loss:0.8749
# timer: 9.4917
# -----------------
# Epoch149/500
# -----------------
#  (train)
# -------------
# epoch 149 || Epoch_D_Loss:0.8397 || Epoch_G_Loss:1.0230
# timer: 9.2657
# -----------------
# Epoch150/500
# -----------------
#  (train)
# -------------
# epoch 150 || Epoch_D_Loss:0.7976 || Epoch_G_Loss:0.9431
# timer: 9.3301
# -----------------
# Epoch151/500
# -----------------
#  (train)
# -------------
# epoch 151 || Epoch_D_Loss:0.7418 || Epoch_G_Loss:1.0929
# timer: 9.2951
# -----------------
# Epoch152/500
# -----------------
#  (train)
# -------------
# epoch 152 || Epoch_D_Loss:0.8234 || Epoch_G_Loss:0.9707
# timer: 9.3524
# -----------------
# Epoch153/500
# -----------------
#  (train)
# -------------
# epoch 153 || Epoch_D_Loss:0.7422 || Epoch_G_Loss:0.9160
# timer: 9.2337
# -----------------
# Epoch154/500
# -----------------
#  (train)
# -------------
# epoch 154 || Epoch_D_Loss:0.8105 || Epoch_G_Loss:1.0411
# timer: 9.2797
# -----------------
# Epoch155/500
# -----------------
#  (train)
# -------------
# epoch 155 || Epoch_D_Loss:0.7585 || Epoch_G_Loss:1.0630
# timer: 9.4180
# -----------------
# Epoch156/500
# -----------------
#  (train)
# -------------
# epoch 156 || Epoch_D_Loss:0.8089 || Epoch_G_Loss:1.0597
# timer: 9.2830
# -----------------
# Epoch157/500
# -----------------
#  (train)
# -------------
# epoch 157 || Epoch_D_Loss:0.7240 || Epoch_G_Loss:1.0765
# timer: 9.3808
# -----------------
# Epoch158/500
# -----------------
#  (train)
# -------------
# epoch 158 || Epoch_D_Loss:0.7064 || Epoch_G_Loss:1.1716
# timer: 9.3223
# -----------------
# Epoch159/500
# -----------------
#  (train)
# -------------
# epoch 159 || Epoch_D_Loss:0.7881 || Epoch_G_Loss:1.0015
# timer: 9.4177
# -----------------
# Epoch160/500
# -----------------
#  (train)
# -------------
# epoch 160 || Epoch_D_Loss:0.6718 || Epoch_G_Loss:1.0723
# timer: 9.3736
# -----------------
# Epoch161/500
# -----------------
#  (train)
# -------------
# epoch 161 || Epoch_D_Loss:0.6793 || Epoch_G_Loss:0.9524
# timer: 9.4774
# -----------------
# Epoch162/500
# -----------------
#  (train)
# -------------
# epoch 162 || Epoch_D_Loss:0.7546 || Epoch_G_Loss:1.0927
# timer: 9.3332
# -----------------
# Epoch163/500
# -----------------
#  (train)
# -------------
# epoch 163 || Epoch_D_Loss:0.6600 || Epoch_G_Loss:1.1367
# timer: 9.3173
# -----------------
# Epoch164/500
# -----------------
#  (train)
# -------------
# epoch 164 || Epoch_D_Loss:0.7144 || Epoch_G_Loss:1.1721
# timer: 9.3306
# -----------------
# Epoch165/500
# -----------------
#  (train)
# -------------
# epoch 165 || Epoch_D_Loss:0.7010 || Epoch_G_Loss:1.1828
# timer: 9.3607
# -----------------
# Epoch166/500
# -----------------
#  (train)
# -------------
# epoch 166 || Epoch_D_Loss:0.7595 || Epoch_G_Loss:1.0774
# timer: 9.4469
# -----------------
# Epoch167/500
# -----------------
#  (train)
# -------------
# epoch 167 || Epoch_D_Loss:0.6740 || Epoch_G_Loss:1.2854
# timer: 9.4103
# -----------------
# Epoch168/500
# -----------------
#  (train)
# -------------
# epoch 168 || Epoch_D_Loss:0.7099 || Epoch_G_Loss:1.0562
# timer: 9.2963
# -----------------
# Epoch169/500
# -----------------
#  (train)
# -------------
# epoch 169 || Epoch_D_Loss:0.6686 || Epoch_G_Loss:1.1061
# timer: 9.4502
# -----------------
# Epoch170/500
# -----------------
#  (train)
# -------------
# epoch 170 || Epoch_D_Loss:0.6408 || Epoch_G_Loss:1.1675
# timer: 9.2859
# -----------------
# Epoch171/500
# -----------------
#  (train)
# -------------
# epoch 171 || Epoch_D_Loss:0.6427 || Epoch_G_Loss:1.2023
# timer: 9.1509
# -----------------
# Epoch172/500
# -----------------
#  (train)
# -------------
# epoch 172 || Epoch_D_Loss:0.5737 || Epoch_G_Loss:1.3017
# timer: 9.1282
# -----------------
# Epoch173/500
# -----------------
#  (train)
# -------------
# epoch 173 || Epoch_D_Loss:0.6823 || Epoch_G_Loss:1.2492
# timer: 9.1099
# -----------------
# Epoch174/500
# -----------------
#  (train)
# -------------
# epoch 174 || Epoch_D_Loss:0.6401 || Epoch_G_Loss:1.1383
# timer: 9.1974
# -----------------
# Epoch175/500
# -----------------
#  (train)
# -------------
# epoch 175 || Epoch_D_Loss:0.5992 || Epoch_G_Loss:1.2769
# timer: 9.1218
# -----------------
# Epoch176/500
# -----------------
#  (train)
# -------------
# epoch 176 || Epoch_D_Loss:0.5310 || Epoch_G_Loss:1.3444
# timer: 9.1269
# -----------------
# Epoch177/500
# -----------------
#  (train)
# -------------
# epoch 177 || Epoch_D_Loss:0.5938 || Epoch_G_Loss:1.3337
# timer: 9.0824
# -----------------
# Epoch178/500
# -----------------
#  (train)
# -------------
# epoch 178 || Epoch_D_Loss:0.5434 || Epoch_G_Loss:1.3328
# timer: 9.0642
# -----------------
# Epoch179/500
# -----------------
#  (train)
# -------------
# epoch 179 || Epoch_D_Loss:0.6080 || Epoch_G_Loss:1.2153
# timer: 9.1011
# -----------------
# Epoch180/500
# -----------------
#  (train)
# -------------
# epoch 180 || Epoch_D_Loss:0.6267 || Epoch_G_Loss:1.3904
# timer: 9.1409
# -----------------
# Epoch181/500
# -----------------
#  (train)
# -------------
# epoch 181 || Epoch_D_Loss:0.6042 || Epoch_G_Loss:1.4168
# timer: 9.1016
# -----------------
# Epoch182/500
# -----------------
#  (train)
# -------------
# epoch 182 || Epoch_D_Loss:0.6115 || Epoch_G_Loss:1.3590
# timer: 9.0507
# -----------------
# Epoch183/500
# -----------------
#  (train)
# -------------
# epoch 183 || Epoch_D_Loss:0.5589 || Epoch_G_Loss:1.2661
# timer: 9.0982
# -----------------
# Epoch184/500
# -----------------
#  (train)
# -------------
# epoch 184 || Epoch_D_Loss:0.5344 || Epoch_G_Loss:1.4555
# timer: 9.0215
# -----------------
# Epoch185/500
# -----------------
#  (train)
# -------------
# epoch 185 || Epoch_D_Loss:0.5521 || Epoch_G_Loss:1.2982
# timer: 9.0503
# -----------------
# Epoch186/500
# -----------------
#  (train)
# -------------
# epoch 186 || Epoch_D_Loss:0.5503 || Epoch_G_Loss:1.4296
# timer: 9.1278
# -----------------
# Epoch187/500
# -----------------
#  (train)
# -------------
# epoch 187 || Epoch_D_Loss:0.5280 || Epoch_G_Loss:1.4283
# timer: 9.1925
# -----------------
# Epoch188/500
# -----------------
#  (train)
# -------------
# epoch 188 || Epoch_D_Loss:0.5600 || Epoch_G_Loss:1.5600
# timer: 9.0981
# -----------------
# Epoch189/500
# -----------------
#  (train)
# -------------
# epoch 189 || Epoch_D_Loss:0.4702 || Epoch_G_Loss:1.4270
# timer: 9.1098
# -----------------
# Epoch190/500
# -----------------
#  (train)
# -------------
# epoch 190 || Epoch_D_Loss:0.5365 || Epoch_G_Loss:1.4393
# timer: 9.0633
# -----------------
# Epoch191/500
# -----------------
#  (train)
# -------------
# epoch 191 || Epoch_D_Loss:0.5235 || Epoch_G_Loss:1.4778
# timer: 9.0729
# -----------------
# Epoch192/500
# -----------------
#  (train)
# -------------
# epoch 192 || Epoch_D_Loss:0.5180 || Epoch_G_Loss:1.5012
# timer: 9.0449
# -----------------
# Epoch193/500
# -----------------
#  (train)
# -------------
# epoch 193 || Epoch_D_Loss:0.5330 || Epoch_G_Loss:1.4342
# timer: 8.9621
# -----------------
# Epoch194/500
# -----------------
#  (train)
# -------------
# epoch 194 || Epoch_D_Loss:0.4919 || Epoch_G_Loss:1.5898
# timer: 9.0413
# -----------------
# Epoch195/500
# -----------------
#  (train)
# -------------
# epoch 195 || Epoch_D_Loss:0.4970 || Epoch_G_Loss:1.5498
# timer: 8.9956
# -----------------
# Epoch196/500
# -----------------
#  (train)
# -------------
# epoch 196 || Epoch_D_Loss:0.5118 || Epoch_G_Loss:1.5080
# timer: 9.0274
# -----------------
# Epoch197/500
# -----------------
#  (train)
# -------------
# epoch 197 || Epoch_D_Loss:0.5291 || Epoch_G_Loss:1.5720
# timer: 8.9930
# -----------------
# Epoch198/500
# -----------------
#  (train)
# -------------
# epoch 198 || Epoch_D_Loss:0.4535 || Epoch_G_Loss:1.4990
# timer: 9.0456
# -----------------
# Epoch199/500
# -----------------
#  (train)
# -------------
# epoch 199 || Epoch_D_Loss:0.3884 || Epoch_G_Loss:1.4375
# timer: 8.9943
# -----------------
# Epoch200/500
# -----------------
#  (train)
# -------------
# epoch 200 || Epoch_D_Loss:0.4752 || Epoch_G_Loss:1.6185
# timer: 9.0897
# -----------------
# Epoch201/500
# -----------------
#  (train)
# -------------
# epoch 201 || Epoch_D_Loss:0.4638 || Epoch_G_Loss:1.5545
# timer: 9.4219
# -----------------
# Epoch202/500
# -----------------
#  (train)
# -------------
# epoch 202 || Epoch_D_Loss:0.5058 || Epoch_G_Loss:1.5711
# timer: 9.1064
# -----------------
# Epoch203/500
# -----------------
#  (train)
# -------------
# epoch 203 || Epoch_D_Loss:0.4822 || Epoch_G_Loss:1.5219
# timer: 9.0073
# -----------------
# Epoch204/500
# -----------------
#  (train)
# -------------
# epoch 204 || Epoch_D_Loss:0.4209 || Epoch_G_Loss:1.4911
# timer: 9.1889
# -----------------
# Epoch205/500
# -----------------
#  (train)
# -------------
# epoch 205 || Epoch_D_Loss:0.4631 || Epoch_G_Loss:1.6302
# timer: 9.2113
# -----------------
# Epoch206/500
# -----------------
#  (train)
# -------------
# epoch 206 || Epoch_D_Loss:0.4664 || Epoch_G_Loss:1.4900
# timer: 9.2770
# -----------------
# Epoch207/500
# -----------------
#  (train)
# -------------
# epoch 207 || Epoch_D_Loss:0.4168 || Epoch_G_Loss:1.7312
# timer: 9.2212
# -----------------
# Epoch208/500
# -----------------
#  (train)
# -------------
# epoch 208 || Epoch_D_Loss:0.4226 || Epoch_G_Loss:1.6508
# timer: 9.1326
# -----------------
# Epoch209/500
# -----------------
#  (train)
# -------------
# epoch 209 || Epoch_D_Loss:0.4544 || Epoch_G_Loss:1.6521
# timer: 9.0908
# -----------------
# Epoch210/500
# -----------------
#  (train)
# -------------
# epoch 210 || Epoch_D_Loss:0.4150 || Epoch_G_Loss:1.7584
# timer: 9.0679
# -----------------
# Epoch211/500
# -----------------
#  (train)
# -------------
# epoch 211 || Epoch_D_Loss:0.3949 || Epoch_G_Loss:1.7398
# timer: 9.0887
# -----------------
# Epoch212/500
# -----------------
#  (train)
# -------------
# epoch 212 || Epoch_D_Loss:0.3451 || Epoch_G_Loss:1.6298
# timer: 9.1861
# -----------------
# Epoch213/500
# -----------------
#  (train)
# -------------
# epoch 213 || Epoch_D_Loss:0.4249 || Epoch_G_Loss:1.6391
# timer: 9.0376
# -----------------
# Epoch214/500
# -----------------
#  (train)
# -------------
# epoch 214 || Epoch_D_Loss:0.3241 || Epoch_G_Loss:1.7615
# timer: 9.0393
# -----------------
# Epoch215/500
# -----------------
#  (train)
# -------------
# epoch 215 || Epoch_D_Loss:0.4368 || Epoch_G_Loss:1.8062
# timer: 9.0665
# -----------------
# Epoch216/500
# -----------------
#  (train)
# -------------
# epoch 216 || Epoch_D_Loss:0.3975 || Epoch_G_Loss:1.7804
# timer: 9.0791
# -----------------
# Epoch217/500
# -----------------
#  (train)
# -------------
# epoch 217 || Epoch_D_Loss:0.3999 || Epoch_G_Loss:1.6915
# timer: 8.9855
# -----------------
# Epoch218/500
# -----------------
#  (train)
# -------------
# epoch 218 || Epoch_D_Loss:0.3806 || Epoch_G_Loss:1.8413
# timer: 8.9633
# -----------------
# Epoch219/500
# -----------------
#  (train)
# -------------
# epoch 219 || Epoch_D_Loss:0.3788 || Epoch_G_Loss:1.7857
# timer: 9.0749
# -----------------
# Epoch220/500
# -----------------
#  (train)
# -------------
# epoch 220 || Epoch_D_Loss:0.3222 || Epoch_G_Loss:1.8568
# timer: 9.0005
# -----------------
# Epoch221/500
# -----------------
#  (train)
# -------------
# epoch 221 || Epoch_D_Loss:0.4223 || Epoch_G_Loss:1.8194
# timer: 9.1244
# -----------------
# Epoch222/500
# -----------------
#  (train)
# -------------
# epoch 222 || Epoch_D_Loss:0.3885 || Epoch_G_Loss:1.8157
# timer: 9.1329
# -----------------
# Epoch223/500
# -----------------
#  (train)
# -------------
# epoch 223 || Epoch_D_Loss:0.3708 || Epoch_G_Loss:1.7630
# timer: 9.0474
# -----------------
# Epoch224/500
# -----------------
#  (train)
# -------------
# epoch 224 || Epoch_D_Loss:0.3145 || Epoch_G_Loss:1.8467
# timer: 9.0179
# -----------------
# Epoch225/500
# -----------------
#  (train)
# -------------
# epoch 225 || Epoch_D_Loss:0.3302 || Epoch_G_Loss:1.9314
# timer: 9.0153
# -----------------
# Epoch226/500
# -----------------
#  (train)
# -------------
# epoch 226 || Epoch_D_Loss:0.3263 || Epoch_G_Loss:1.9006
# timer: 9.0479
# -----------------
# Epoch227/500
# -----------------
#  (train)
# -------------
# epoch 227 || Epoch_D_Loss:0.3234 || Epoch_G_Loss:1.9741
# timer: 9.0598
# -----------------
# Epoch228/500
# -----------------
#  (train)
# -------------
# epoch 228 || Epoch_D_Loss:0.3516 || Epoch_G_Loss:1.9396
# timer: 9.0288
# -----------------
# Epoch229/500
# -----------------
#  (train)
# -------------
# epoch 229 || Epoch_D_Loss:0.3256 || Epoch_G_Loss:1.9721
# timer: 9.0120
# -----------------
# Epoch230/500
# -----------------
#  (train)
# -------------
# epoch 230 || Epoch_D_Loss:0.2801 || Epoch_G_Loss:2.2357
# timer: 9.0675
# -----------------
# Epoch231/500
# -----------------
#  (train)
# -------------
# epoch 231 || Epoch_D_Loss:0.3227 || Epoch_G_Loss:1.8568
# timer: 9.0512
# -----------------
# Epoch232/500
# -----------------
#  (train)
# -------------
# epoch 232 || Epoch_D_Loss:0.3370 || Epoch_G_Loss:1.9095
# timer: 9.0698
# -----------------
# Epoch233/500
# -----------------
#  (train)
# -------------
# epoch 233 || Epoch_D_Loss:0.3196 || Epoch_G_Loss:1.8767
# timer: 9.0995
# -----------------
# Epoch234/500
# -----------------
#  (train)
# -------------
# epoch 234 || Epoch_D_Loss:0.3163 || Epoch_G_Loss:2.1647
# timer: 9.0495
# -----------------
# Epoch235/500
# -----------------
#  (train)
# -------------
# epoch 235 || Epoch_D_Loss:0.2650 || Epoch_G_Loss:2.0498
# timer: 8.9937
# -----------------
# Epoch236/500
# -----------------
#  (train)
# -------------
# epoch 236 || Epoch_D_Loss:0.3156 || Epoch_G_Loss:2.0905
# timer: 9.0392
# -----------------
# Epoch237/500
# -----------------
#  (train)
# -------------
# epoch 237 || Epoch_D_Loss:0.2669 || Epoch_G_Loss:2.1081
# timer: 9.0459
# -----------------
# Epoch238/500
# -----------------
#  (train)
# -------------
# epoch 238 || Epoch_D_Loss:0.2822 || Epoch_G_Loss:2.0244
# timer: 9.0598
# -----------------
# Epoch239/500
# -----------------
#  (train)
# -------------
# epoch 239 || Epoch_D_Loss:0.2548 || Epoch_G_Loss:2.2119
# timer: 9.0703
# -----------------
# Epoch240/500
# -----------------
#  (train)
# -------------
# epoch 240 || Epoch_D_Loss:0.2070 || Epoch_G_Loss:2.0972
# timer: 9.0859
# -----------------
# Epoch241/500
# -----------------
#  (train)
# -------------
# epoch 241 || Epoch_D_Loss:0.2812 || Epoch_G_Loss:2.2189
# timer: 9.2260
# -----------------
# Epoch242/500
# -----------------
#  (train)
# -------------
# epoch 242 || Epoch_D_Loss:0.2564 || Epoch_G_Loss:2.0946
# timer: 9.0838
# -----------------
# Epoch243/500
# -----------------
#  (train)
# -------------
# epoch 243 || Epoch_D_Loss:0.2947 || Epoch_G_Loss:2.1763
# timer: 8.9872
# -----------------
# Epoch244/500
# -----------------
#  (train)
# -------------
# epoch 244 || Epoch_D_Loss:0.3441 || Epoch_G_Loss:2.1263
# timer: 9.0385
# -----------------
# Epoch245/500
# -----------------
#  (train)
# -------------
# epoch 245 || Epoch_D_Loss:0.2635 || Epoch_G_Loss:2.1187
# timer: 9.1067
# -----------------
# Epoch246/500
# -----------------
#  (train)
# -------------
# epoch 246 || Epoch_D_Loss:0.2510 || Epoch_G_Loss:2.1476
# timer: 9.0014
# -----------------
# Epoch247/500
# -----------------
#  (train)
# -------------
# epoch 247 || Epoch_D_Loss:0.2148 || Epoch_G_Loss:2.2008
# timer: 9.0889
# -----------------
# Epoch248/500
# -----------------
#  (train)
# -------------
# epoch 248 || Epoch_D_Loss:0.2717 || Epoch_G_Loss:2.1119
# timer: 9.0333
# -----------------
# Epoch249/500
# -----------------
#  (train)
# -------------
# epoch 249 || Epoch_D_Loss:0.2654 || Epoch_G_Loss:2.1303
# timer: 9.0796
# -----------------
# Epoch250/500
# -----------------
#  (train)
# -------------
# epoch 250 || Epoch_D_Loss:0.2769 || Epoch_G_Loss:2.3403
# timer: 9.0263
# -----------------
# Epoch251/500
# -----------------
#  (train)
# -------------
# epoch 251 || Epoch_D_Loss:0.2805 || Epoch_G_Loss:2.2388
# timer: 9.0593
# -----------------
# Epoch252/500
# -----------------
#  (train)
# -------------
# epoch 252 || Epoch_D_Loss:0.2453 || Epoch_G_Loss:2.0937
# timer: 9.0897
# -----------------
# Epoch253/500
# -----------------
#  (train)
# -------------
# epoch 253 || Epoch_D_Loss:0.2086 || Epoch_G_Loss:2.1981
# timer: 9.0175
# -----------------
# Epoch254/500
# -----------------
#  (train)
# -------------
# epoch 254 || Epoch_D_Loss:0.2448 || Epoch_G_Loss:2.3422
# timer: 9.0187
# -----------------
# Epoch255/500
# -----------------
#  (train)
# -------------
# epoch 255 || Epoch_D_Loss:0.1949 || Epoch_G_Loss:2.3313
# timer: 9.0205
# -----------------
# Epoch256/500
# -----------------
#  (train)
# -------------
# epoch 256 || Epoch_D_Loss:0.2602 || Epoch_G_Loss:2.3135
# timer: 9.0376
# -----------------
# Epoch257/500
# -----------------
#  (train)
# -------------
# epoch 257 || Epoch_D_Loss:0.2539 || Epoch_G_Loss:2.3394
# timer: 8.9858
# -----------------
# Epoch258/500
# -----------------
#  (train)
# -------------
# epoch 258 || Epoch_D_Loss:0.2159 || Epoch_G_Loss:2.2952
# timer: 9.0705
# -----------------
# Epoch259/500
# -----------------
#  (train)
# -------------
# epoch 259 || Epoch_D_Loss:0.2446 || Epoch_G_Loss:2.1155
# timer: 9.0519
# -----------------
# Epoch260/500
# -----------------
#  (train)
# -------------
# epoch 260 || Epoch_D_Loss:0.2428 || Epoch_G_Loss:2.2680
# timer: 8.9964
# -----------------
# Epoch261/500
# -----------------
#  (train)
# -------------
# epoch 261 || Epoch_D_Loss:0.2208 || Epoch_G_Loss:2.3012
# timer: 9.0647
# -----------------
# Epoch262/500
# -----------------
#  (train)
# -------------
# epoch 262 || Epoch_D_Loss:0.2446 || Epoch_G_Loss:2.4446
# timer: 8.9841
# -----------------
# Epoch263/500
# -----------------
#  (train)
# -------------
# epoch 263 || Epoch_D_Loss:0.1926 || Epoch_G_Loss:2.4179
# timer: 8.9899
# -----------------
# Epoch264/500
# -----------------
#  (train)
# -------------
# epoch 264 || Epoch_D_Loss:0.2264 || Epoch_G_Loss:2.5365
# timer: 8.9759
# -----------------
# Epoch265/500
# -----------------
#  (train)
# -------------
# epoch 265 || Epoch_D_Loss:0.1739 || Epoch_G_Loss:2.5661
# timer: 8.9920
# -----------------
# Epoch266/500
# -----------------
#  (train)
# -------------
# epoch 266 || Epoch_D_Loss:0.2293 || Epoch_G_Loss:2.3250
# timer: 9.0869
# -----------------
# Epoch267/500
# -----------------
#  (train)
# -------------
# epoch 267 || Epoch_D_Loss:0.2216 || Epoch_G_Loss:2.4047
# timer: 8.9898
# -----------------
# Epoch268/500
# -----------------
#  (train)
# -------------
# epoch 268 || Epoch_D_Loss:0.1724 || Epoch_G_Loss:2.5177
# timer: 9.0159
# -----------------
# Epoch269/500
# -----------------
#  (train)
# -------------
# epoch 269 || Epoch_D_Loss:0.1760 || Epoch_G_Loss:2.3822
# timer: 9.0500
# -----------------
# Epoch270/500
# -----------------
#  (train)
# -------------
# epoch 270 || Epoch_D_Loss:0.2385 || Epoch_G_Loss:2.5097
# timer: 9.0033
# -----------------
# Epoch271/500
# -----------------
#  (train)
# -------------
# epoch 271 || Epoch_D_Loss:0.1700 || Epoch_G_Loss:2.3683
# timer: 8.9962
# -----------------
# Epoch272/500
# -----------------
#  (train)
# -------------
# epoch 272 || Epoch_D_Loss:0.2271 || Epoch_G_Loss:2.5004
# timer: 9.0431
# -----------------
# Epoch273/500
# -----------------
#  (train)
# -------------
# epoch 273 || Epoch_D_Loss:0.1750 || Epoch_G_Loss:2.6443
# timer: 8.9881
# -----------------
# Epoch274/500
# -----------------
#  (train)
# -------------
# epoch 274 || Epoch_D_Loss:0.1913 || Epoch_G_Loss:2.4974
# timer: 9.0048
# -----------------
# Epoch275/500
# -----------------
#  (train)
# -------------
# epoch 275 || Epoch_D_Loss:0.2176 || Epoch_G_Loss:2.5004
# timer: 9.0950
# -----------------
# Epoch276/500
# -----------------
#  (train)
# -------------
# epoch 276 || Epoch_D_Loss:0.1877 || Epoch_G_Loss:2.6254
# timer: 9.0510
# -----------------
# Epoch277/500
# -----------------
#  (train)
# -------------
# epoch 277 || Epoch_D_Loss:0.1805 || Epoch_G_Loss:2.7774
# timer: 9.0104
# -----------------
# Epoch278/500
# -----------------
#  (train)
# -------------
# epoch 278 || Epoch_D_Loss:0.1924 || Epoch_G_Loss:2.6208
# timer: 9.0368
# -----------------
# Epoch279/500
# -----------------
#  (train)
# -------------
# epoch 279 || Epoch_D_Loss:0.1517 || Epoch_G_Loss:2.6439
# timer: 8.9877
# -----------------
# Epoch280/500
# -----------------
#  (train)
# -------------
# epoch 280 || Epoch_D_Loss:0.1722 || Epoch_G_Loss:2.7450
# timer: 9.0346
# -----------------
# Epoch281/500
# -----------------
#  (train)
# -------------
# epoch 281 || Epoch_D_Loss:0.1492 || Epoch_G_Loss:2.7399
# timer: 9.0713
# -----------------
# Epoch282/500
# -----------------
#  (train)
# -------------
# epoch 282 || Epoch_D_Loss:0.1479 || Epoch_G_Loss:2.6379
# timer: 8.9878
# -----------------
# Epoch283/500
# -----------------
#  (train)
# -------------
# epoch 283 || Epoch_D_Loss:0.1764 || Epoch_G_Loss:2.7447
# timer: 8.9900
# -----------------
# Epoch284/500
# -----------------
#  (train)
# -------------
# epoch 284 || Epoch_D_Loss:0.2101 || Epoch_G_Loss:2.6116
# timer: 9.0865
# -----------------
# Epoch285/500
# -----------------
#  (train)
# -------------
# epoch 285 || Epoch_D_Loss:0.2045 || Epoch_G_Loss:2.8526
# timer: 9.1232
# -----------------
# Epoch286/500
# -----------------
#  (train)
# -------------
# epoch 286 || Epoch_D_Loss:0.1867 || Epoch_G_Loss:2.7261
# timer: 9.0698
# -----------------
# Epoch287/500
# -----------------
#  (train)
# -------------
# epoch 287 || Epoch_D_Loss:0.1341 || Epoch_G_Loss:2.6636
# timer: 8.9854
# -----------------
# Epoch288/500
# -----------------
#  (train)
# -------------
# epoch 288 || Epoch_D_Loss:0.1841 || Epoch_G_Loss:2.7645
# timer: 9.0340
# -----------------
# Epoch289/500
# -----------------
#  (train)
# -------------
# epoch 289 || Epoch_D_Loss:0.2042 || Epoch_G_Loss:2.8273
# timer: 8.9813
# -----------------
# Epoch290/500
# -----------------
#  (train)
# -------------
# epoch 290 || Epoch_D_Loss:0.1602 || Epoch_G_Loss:2.6710
# timer: 8.9637
# -----------------
# Epoch291/500
# -----------------
#  (train)
# -------------
# epoch 291 || Epoch_D_Loss:0.1399 || Epoch_G_Loss:2.8169
# timer: 9.0264
# -----------------
# Epoch292/500
# -----------------
#  (train)
# -------------
# epoch 292 || Epoch_D_Loss:0.1509 || Epoch_G_Loss:2.7469
# timer: 9.0049
# -----------------
# Epoch293/500
# -----------------
#  (train)
# -------------
# epoch 293 || Epoch_D_Loss:0.1450 || Epoch_G_Loss:2.7637
# timer: 9.0188
# -----------------
# Epoch294/500
# -----------------
#  (train)
# -------------
# epoch 294 || Epoch_D_Loss:0.1600 || Epoch_G_Loss:2.7439
# timer: 8.9734
# -----------------
# Epoch295/500
# -----------------
#  (train)
# -------------
# epoch 295 || Epoch_D_Loss:0.1589 || Epoch_G_Loss:2.7515
# timer: 9.0335
# -----------------
# Epoch296/500
# -----------------
#  (train)
# -------------
# epoch 296 || Epoch_D_Loss:0.2084 || Epoch_G_Loss:2.8271
# timer: 8.9728
# -----------------
# Epoch297/500
# -----------------
#  (train)
# -------------
# epoch 297 || Epoch_D_Loss:0.1483 || Epoch_G_Loss:2.7694
# timer: 9.0293
# -----------------
# Epoch298/500
# -----------------
#  (train)
# -------------
# epoch 298 || Epoch_D_Loss:0.1485 || Epoch_G_Loss:2.8097
# timer: 9.0688
# -----------------
# Epoch299/500
# -----------------
#  (train)
# -------------
# epoch 299 || Epoch_D_Loss:0.1792 || Epoch_G_Loss:2.6468
# timer: 9.0406
# -----------------
# Epoch300/500
# -----------------
#  (train)
# -------------
# epoch 300 || Epoch_D_Loss:0.1532 || Epoch_G_Loss:2.8036
# timer: 8.9737
# -----------------
# Epoch301/500
# -----------------
#  (train)
# -------------
# epoch 301 || Epoch_D_Loss:0.1452 || Epoch_G_Loss:2.9036
# timer: 9.0428
# -----------------
# Epoch302/500
# -----------------
#  (train)
# -------------
# epoch 302 || Epoch_D_Loss:0.1855 || Epoch_G_Loss:2.6426
# timer: 9.0875
# -----------------
# Epoch303/500
# -----------------
#  (train)
# -------------
# epoch 303 || Epoch_D_Loss:0.1290 || Epoch_G_Loss:2.6481
# timer: 8.9680
# -----------------
# Epoch304/500
# -----------------
#  (train)
# -------------
# epoch 304 || Epoch_D_Loss:0.1457 || Epoch_G_Loss:2.8281
# timer: 9.0629
# -----------------
# Epoch305/500
# -----------------
#  (train)
# -------------
# epoch 305 || Epoch_D_Loss:0.1204 || Epoch_G_Loss:2.7206
# timer: 9.0652
# -----------------
# Epoch306/500
# -----------------
#  (train)
# -------------
# epoch 306 || Epoch_D_Loss:0.1529 || Epoch_G_Loss:2.7732
# timer: 9.0736
# -----------------
# Epoch307/500
# -----------------
#  (train)
# -------------
# epoch 307 || Epoch_D_Loss:0.1577 || Epoch_G_Loss:2.8423
# timer: 8.9873
# -----------------
# Epoch308/500
# -----------------
#  (train)
# -------------
# epoch 308 || Epoch_D_Loss:0.1578 || Epoch_G_Loss:2.9067
# timer: 9.0055
# -----------------
# Epoch309/500
# -----------------
#  (train)
# -------------
# epoch 309 || Epoch_D_Loss:0.1463 || Epoch_G_Loss:2.8585
# timer: 9.0837
# -----------------
# Epoch310/500
# -----------------
#  (train)
# -------------
# epoch 310 || Epoch_D_Loss:0.1271 || Epoch_G_Loss:3.0013
# timer: 9.1367
# -----------------
# Epoch311/500
# -----------------
#  (train)
# -------------
# epoch 311 || Epoch_D_Loss:0.1160 || Epoch_G_Loss:3.0790
# timer: 9.0697
# -----------------
# Epoch312/500
# -----------------
#  (train)
# -------------
# epoch 312 || Epoch_D_Loss:0.1240 || Epoch_G_Loss:3.0182
# timer: 8.9814
# -----------------
# Epoch313/500
# -----------------
#  (train)
# -------------
# epoch 313 || Epoch_D_Loss:0.1379 || Epoch_G_Loss:2.7242
# timer: 9.0613
# -----------------
# Epoch314/500
# -----------------
#  (train)
# -------------
# epoch 314 || Epoch_D_Loss:0.1417 || Epoch_G_Loss:2.9962
# timer: 9.0231
# -----------------
# Epoch315/500
# -----------------
#  (train)
# -------------
# epoch 315 || Epoch_D_Loss:0.0743 || Epoch_G_Loss:3.0319
# timer: 8.9641
# -----------------
# Epoch316/500
# -----------------
#  (train)
# -------------
# epoch 316 || Epoch_D_Loss:0.1374 || Epoch_G_Loss:2.9631
# timer: 8.9800
# -----------------
# Epoch317/500
# -----------------
#  (train)
# -------------
# epoch 317 || Epoch_D_Loss:0.1259 || Epoch_G_Loss:2.8817
# timer: 9.0299
# -----------------
# Epoch318/500
# -----------------
#  (train)
# -------------
# epoch 318 || Epoch_D_Loss:0.1269 || Epoch_G_Loss:3.1479
# timer: 9.0056
# -----------------
# Epoch319/500
# -----------------
#  (train)
# -------------
# epoch 319 || Epoch_D_Loss:0.1247 || Epoch_G_Loss:3.0033
# timer: 8.9913
# -----------------
# Epoch320/500
# -----------------
#  (train)
# -------------
# epoch 320 || Epoch_D_Loss:0.1116 || Epoch_G_Loss:3.0118
# timer: 9.0500
# -----------------
# Epoch321/500
# -----------------
#  (train)
# -------------
# epoch 321 || Epoch_D_Loss:0.1185 || Epoch_G_Loss:3.1677
# timer: 9.1147
# -----------------
# Epoch322/500
# -----------------
#  (train)
# -------------
# epoch 322 || Epoch_D_Loss:0.1111 || Epoch_G_Loss:3.2535
# timer: 9.0295
# -----------------
# Epoch323/500
# -----------------
#  (train)
# -------------
# epoch 323 || Epoch_D_Loss:0.1353 || Epoch_G_Loss:3.3923
# timer: 8.9912
# -----------------
# Epoch324/500
# -----------------
#  (train)
# -------------
# epoch 324 || Epoch_D_Loss:0.1260 || Epoch_G_Loss:3.1016
# timer: 9.1003
# -----------------
# Epoch325/500
# -----------------
#  (train)
# -------------
# epoch 325 || Epoch_D_Loss:0.1396 || Epoch_G_Loss:3.1009
# timer: 9.0182
# -----------------
# Epoch326/500
# -----------------
#  (train)
# -------------
# epoch 326 || Epoch_D_Loss:0.1351 || Epoch_G_Loss:3.1636
# timer: 8.9957
# -----------------
# Epoch327/500
# -----------------
#  (train)
# -------------
# epoch 327 || Epoch_D_Loss:0.0983 || Epoch_G_Loss:2.9987
# timer: 8.9884
# -----------------
# Epoch328/500
# -----------------
#  (train)
# -------------
# epoch 328 || Epoch_D_Loss:0.1489 || Epoch_G_Loss:3.0839
# timer: 9.0394
# -----------------
# Epoch329/500
# -----------------
#  (train)
# -------------
# epoch 329 || Epoch_D_Loss:0.1276 || Epoch_G_Loss:3.0421
# timer: 8.9871
# -----------------
# Epoch330/500
# -----------------
#  (train)
# -------------
# epoch 330 || Epoch_D_Loss:0.1029 || Epoch_G_Loss:3.1190
# timer: 8.9946
# -----------------
# Epoch331/500
# -----------------
#  (train)
# -------------
# epoch 331 || Epoch_D_Loss:0.1271 || Epoch_G_Loss:3.1711
# timer: 9.0922
# -----------------
# Epoch332/500
# -----------------
#  (train)
# -------------
# epoch 332 || Epoch_D_Loss:0.1204 || Epoch_G_Loss:2.9397
# timer: 8.9596
# -----------------
# Epoch333/500
# -----------------
#  (train)
# -------------
# epoch 333 || Epoch_D_Loss:0.1259 || Epoch_G_Loss:3.0379
# timer: 8.9718
# -----------------
# Epoch334/500
# -----------------
#  (train)
# -------------
# epoch 334 || Epoch_D_Loss:0.1095 || Epoch_G_Loss:3.1184
# timer: 8.9764
# -----------------
# Epoch335/500
# -----------------
#  (train)
# -------------
# epoch 335 || Epoch_D_Loss:0.1194 || Epoch_G_Loss:3.0617
# timer: 9.0336
# -----------------
# Epoch336/500
# -----------------
#  (train)
# -------------
# epoch 336 || Epoch_D_Loss:0.1311 || Epoch_G_Loss:3.0481
# timer: 8.9748
# ...
# Epoch388/500
# -----------------
#  (train)
# -------------
# epoch 388 || Epoch_D_Loss:0.1038 || Epoch_G_Loss:3.3659
# timer: 9.0851
# -----------------
# Epoch389/500
# -----------------
#  (train)
# -------------
# epoch 389 || Epoch_D_Loss:0.0806 || Epoch_G_Loss:3.3120
# timer: 9.1042
# -----------------
# Epoch390/500
# -----------------
#  (train)
# -------------
# epoch 390 || Epoch_D_Loss:0.0886 || Epoch_G_Loss:3.3546
# timer: 9.0989
# -----------------
# Epoch391/500
# -----------------
#  (train)
# -------------
# epoch 391 || Epoch_D_Loss:0.0936 || Epoch_G_Loss:3.5504
# timer: 9.1071
# -----------------
# Epoch392/500
# -----------------
#  (train)
# -------------
# epoch 392 || Epoch_D_Loss:0.0913 || Epoch_G_Loss:3.3584
# timer: 9.1158
# -----------------
# Epoch393/500
# -----------------
#  (train)
# -------------
# epoch 393 || Epoch_D_Loss:0.0950 || Epoch_G_Loss:3.5378
# timer: 9.0589
# -----------------
# Epoch394/500
# -----------------
#  (train)
# -------------
# epoch 394 || Epoch_D_Loss:0.0543 || Epoch_G_Loss:3.5978
# timer: 9.0470
# -----------------
# Epoch395/500
# -----------------
#  (train)
# -------------
# epoch 395 || Epoch_D_Loss:0.0614 || Epoch_G_Loss:3.5743
# timer: 9.0066
# -----------------
# Epoch396/500
# -----------------
#  (train)
# -------------
# epoch 396 || Epoch_D_Loss:0.1038 || Epoch_G_Loss:3.5227
# timer: 9.2080
# -----------------
# Epoch397/500
# -----------------
#  (train)
# -------------
# epoch 397 || Epoch_D_Loss:0.0712 || Epoch_G_Loss:3.7541
# timer: 9.0250
# -----------------
# Epoch398/500
# -----------------
#  (train)
# -------------
# epoch 398 || Epoch_D_Loss:0.0994 || Epoch_G_Loss:3.4466
# timer: 9.0454
# -----------------
# Epoch399/500
# -----------------
#  (train)
# -------------
# epoch 399 || Epoch_D_Loss:0.0650 || Epoch_G_Loss:3.5489
# timer: 9.0658
# -----------------
# Epoch400/500
# -----------------
#  (train)
# -------------
# epoch 400 || Epoch_D_Loss:0.0974 || Epoch_G_Loss:3.6035
# timer: 9.1094
# -----------------
# Epoch401/500
# -----------------
#  (train)
# -------------
# epoch 401 || Epoch_D_Loss:0.1154 || Epoch_G_Loss:3.2912
# timer: 9.1339
# -----------------
# Epoch402/500
# -----------------
#  (train)
# -------------
# epoch 402 || Epoch_D_Loss:0.1124 || Epoch_G_Loss:3.3592
# timer: 9.0947
# -----------------
# Epoch403/500
# -----------------
#  (train)
# -------------
# epoch 403 || Epoch_D_Loss:0.0940 || Epoch_G_Loss:3.4164
# timer: 9.1754
# -----------------
# Epoch404/500
# -----------------
#  (train)
# -------------
# epoch 404 || Epoch_D_Loss:0.0890 || Epoch_G_Loss:3.3964
# timer: 8.9958
# -----------------
# Epoch405/500
# -----------------
#  (train)
# -------------
# epoch 405 || Epoch_D_Loss:0.0963 || Epoch_G_Loss:3.3696
# timer: 9.0288
# -----------------
# Epoch406/500
# -----------------
#  (train)
# -------------
# epoch 406 || Epoch_D_Loss:0.0552 || Epoch_G_Loss:3.7424
# timer: 9.0498
# -----------------
# Epoch407/500
# -----------------
#  (train)
# -------------
# epoch 407 || Epoch_D_Loss:0.1011 || Epoch_G_Loss:3.6617
# timer: 9.0962
# -----------------
# Epoch408/500
# -----------------
#  (train)
# -------------
# epoch 408 || Epoch_D_Loss:0.0669 || Epoch_G_Loss:3.4981
# timer: 9.0550
# -----------------
# Epoch409/500
# -----------------
#  (train)
# -------------
# epoch 409 || Epoch_D_Loss:0.0859 || Epoch_G_Loss:3.8812
# timer: 9.0508
# -----------------
# Epoch410/500
# -----------------
#  (train)
# -------------
# epoch 410 || Epoch_D_Loss:0.0858 || Epoch_G_Loss:3.7244
# timer: 9.1280
# -----------------
# Epoch411/500
# -----------------
#  (train)
# -------------
# epoch 411 || Epoch_D_Loss:0.0771 || Epoch_G_Loss:3.4046
# timer: 9.2141
# -----------------
# Epoch412/500
# -----------------
#  (train)
# -------------
# epoch 412 || Epoch_D_Loss:0.0679 || Epoch_G_Loss:3.5493
# timer: 9.0464
# -----------------
# Epoch413/500
# -----------------
#  (train)
# -------------
# epoch 413 || Epoch_D_Loss:0.0882 || Epoch_G_Loss:3.6147
# timer: 9.0668
# -----------------
# Epoch414/500
# -----------------
#  (train)
# -------------
# epoch 414 || Epoch_D_Loss:0.0960 || Epoch_G_Loss:3.6042
# timer: 9.1011
# -----------------
# Epoch415/500
# -----------------
#  (train)
# -------------
# epoch 415 || Epoch_D_Loss:0.1071 || Epoch_G_Loss:3.3661
# timer: 9.0268
# -----------------
# Epoch416/500
# -----------------
#  (train)
# -------------
# epoch 416 || Epoch_D_Loss:0.0967 || Epoch_G_Loss:3.3025
# timer: 9.0079
# -----------------
# Epoch417/500
# -----------------
#  (train)
# -------------
# epoch 417 || Epoch_D_Loss:0.0989 || Epoch_G_Loss:3.5152
# timer: 9.1798
# -----------------
# Epoch418/500
# -----------------
#  (train)
# -------------
# epoch 418 || Epoch_D_Loss:0.0953 || Epoch_G_Loss:3.2856
# timer: 9.1557
# -----------------
# Epoch419/500
# -----------------
#  (train)
# -------------
# epoch 419 || Epoch_D_Loss:0.0783 || Epoch_G_Loss:3.3927
# timer: 9.0955
# -----------------
# Epoch420/500
# -----------------
#  (train)
# -------------
# epoch 420 || Epoch_D_Loss:0.0675 || Epoch_G_Loss:3.5526
# timer: 9.1112
# -----------------
# Epoch421/500
# -----------------
#  (train)
# -------------
# epoch 421 || Epoch_D_Loss:0.0840 || Epoch_G_Loss:3.4122
# timer: 9.2353
# -----------------
# Epoch422/500
# -----------------
#  (train)
# -------------
# epoch 422 || Epoch_D_Loss:0.0901 || Epoch_G_Loss:3.6038
# timer: 9.1485
# -----------------
# Epoch423/500
# -----------------
#  (train)
# -------------
# epoch 423 || Epoch_D_Loss:0.0832 || Epoch_G_Loss:3.5174
# timer: 9.1304
# -----------------
# Epoch424/500
# -----------------
#  (train)
# -------------
# epoch 424 || Epoch_D_Loss:0.0845 || Epoch_G_Loss:3.6863
# timer: 9.1359
# -----------------
# Epoch425/500
# -----------------
#  (train)
# -------------
# epoch 425 || Epoch_D_Loss:0.0690 || Epoch_G_Loss:3.6637
# timer: 9.2072
# -----------------
# Epoch426/500
# -----------------
#  (train)
# -------------
# epoch 426 || Epoch_D_Loss:0.0413 || Epoch_G_Loss:3.6070
# timer: 9.2497
# -----------------
# Epoch427/500
# -----------------
#  (train)
# -------------
# epoch 427 || Epoch_D_Loss:0.0408 || Epoch_G_Loss:3.5080
# timer: 9.1666
# -----------------
# Epoch428/500
# -----------------
#  (train)
# -------------
# epoch 428 || Epoch_D_Loss:0.0672 || Epoch_G_Loss:4.0009
# timer: 9.2755
# -----------------
# Epoch429/500
# -----------------
#  (train)
# -------------
# epoch 429 || Epoch_D_Loss:0.0789 || Epoch_G_Loss:3.8189
# timer: 9.1380
# -----------------
# Epoch430/500
# -----------------
#  (train)
# -------------
# epoch 430 || Epoch_D_Loss:0.0737 || Epoch_G_Loss:3.5098
# timer: 9.1051
# -----------------
# Epoch431/500
# -----------------
#  (train)
# -------------
# epoch 431 || Epoch_D_Loss:0.0617 || Epoch_G_Loss:3.8156
# timer: 9.1199
# -----------------
# Epoch432/500
# -----------------
#  (train)
# -------------
# epoch 432 || Epoch_D_Loss:0.0932 || Epoch_G_Loss:3.6276
# timer: 9.1162
# -----------------
# Epoch433/500
# -----------------
#  (train)
# -------------
# epoch 433 || Epoch_D_Loss:0.0833 || Epoch_G_Loss:3.5948
# timer: 9.1215
# -----------------
# Epoch434/500
# -----------------
#  (train)
# -------------
# epoch 434 || Epoch_D_Loss:0.0766 || Epoch_G_Loss:3.5090
# timer: 9.1072
# -----------------
# Epoch435/500
# -----------------
#  (train)
# -------------
# epoch 435 || Epoch_D_Loss:0.0906 || Epoch_G_Loss:3.7151
# timer: 9.2238
# -----------------
# Epoch436/500
# -----------------
#  (train)
# -------------
# epoch 436 || Epoch_D_Loss:0.0416 || Epoch_G_Loss:3.6049
# timer: 9.2725
# -----------------
# Epoch437/500
# -----------------
#  (train)
# -------------
# epoch 437 || Epoch_D_Loss:0.0656 || Epoch_G_Loss:3.4835
# timer: 9.1957
# -----------------
# Epoch438/500
# -----------------
#  (train)
# -------------
# epoch 438 || Epoch_D_Loss:0.0644 || Epoch_G_Loss:3.5577
# timer: 9.0949
# -----------------
# Epoch439/500
# -----------------
#  (train)
# -------------
# epoch 439 || Epoch_D_Loss:0.0545 || Epoch_G_Loss:3.6253
# timer: 9.1027
# -----------------
# Epoch440/500
# -----------------
#  (train)
# -------------
# epoch 440 || Epoch_D_Loss:0.0534 || Epoch_G_Loss:3.5223
# timer: 9.1043
# -----------------
# Epoch441/500
# -----------------
#  (train)
# -------------
# epoch 441 || Epoch_D_Loss:0.0708 || Epoch_G_Loss:3.4288
# timer: 9.2371
# -----------------
# Epoch442/500
# -----------------
#  (train)
# -------------
# epoch 442 || Epoch_D_Loss:0.0841 || Epoch_G_Loss:3.7652
# timer: 9.0908
# -----------------
# Epoch443/500
# -----------------
#  (train)
# -------------
# epoch 443 || Epoch_D_Loss:0.0721 || Epoch_G_Loss:3.5680
# timer: 9.2446
# -----------------
# Epoch444/500
# -----------------
#  (train)
# -------------
# epoch 444 || Epoch_D_Loss:0.0621 || Epoch_G_Loss:3.6572
# timer: 9.2420
# -----------------
# Epoch445/500
# -----------------
#  (train)
# -------------
# epoch 445 || Epoch_D_Loss:0.0701 || Epoch_G_Loss:3.7086
# timer: 9.3024
# -----------------
# Epoch446/500
# -----------------
#  (train)
# -------------
# epoch 446 || Epoch_D_Loss:0.0688 || Epoch_G_Loss:3.3920
# timer: 9.3381
# -----------------
# Epoch447/500
# -----------------
#  (train)
# -------------
# epoch 447 || Epoch_D_Loss:0.0859 || Epoch_G_Loss:3.5414
# timer: 9.1625
# -----------------
# Epoch448/500
# -----------------
#  (train)
# -------------
# epoch 448 || Epoch_D_Loss:0.0594 || Epoch_G_Loss:3.5610
# timer: 9.1076
# -----------------
# Epoch449/500
# -----------------
#  (train)
# -------------
# epoch 449 || Epoch_D_Loss:0.0544 || Epoch_G_Loss:3.7015
# timer: 9.1447
# -----------------
# Epoch450/500
# -----------------
#  (train)
# -------------
# epoch 450 || Epoch_D_Loss:0.0754 || Epoch_G_Loss:3.9057
# timer: 9.1906
# -----------------
# Epoch451/500
# -----------------
#  (train)
# -------------
# epoch 451 || Epoch_D_Loss:0.0638 || Epoch_G_Loss:3.6261
# timer: 9.1193
# -----------------
# Epoch452/500
# -----------------
#  (train)
# -------------
# epoch 452 || Epoch_D_Loss:0.1142 || Epoch_G_Loss:3.7121
# timer: 9.1641
# -----------------
# Epoch453/500
# -----------------
#  (train)
# -------------
# epoch 453 || Epoch_D_Loss:0.0714 || Epoch_G_Loss:3.5616
# timer: 9.1312
# -----------------
# Epoch454/500
# -----------------
#  (train)
# -------------
# epoch 454 || Epoch_D_Loss:0.0668 || Epoch_G_Loss:3.8004
# timer: 9.1585
# -----------------
# Epoch455/500
# -----------------
#  (train)
# -------------
# epoch 455 || Epoch_D_Loss:0.0783 || Epoch_G_Loss:3.6421
# timer: 9.1920
# -----------------
# Epoch456/500
# -----------------
#  (train)
# -------------
# epoch 456 || Epoch_D_Loss:0.0610 || Epoch_G_Loss:3.5596
# timer: 9.2211
# -----------------
# Epoch457/500
# -----------------
#  (train)
# -------------
# epoch 457 || Epoch_D_Loss:0.0715 || Epoch_G_Loss:3.6341
# timer: 9.2494
# -----------------
# Epoch458/500
# -----------------
#  (train)
# -------------
# epoch 458 || Epoch_D_Loss:0.0778 || Epoch_G_Loss:3.8593
# timer: 9.1419
# -----------------
# Epoch459/500
# -----------------
#  (train)
# -------------
# epoch 459 || Epoch_D_Loss:0.0614 || Epoch_G_Loss:3.5549
# timer: 9.0653
# -----------------
# Epoch460/500
# -----------------
#  (train)
# -------------
# epoch 460 || Epoch_D_Loss:0.1008 || Epoch_G_Loss:3.5762
# timer: 9.1234
# -----------------
# Epoch461/500
# -----------------
#  (train)
# -------------
# epoch 461 || Epoch_D_Loss:0.0736 || Epoch_G_Loss:3.5428
# timer: 9.2697
# -----------------
# Epoch462/500
# -----------------
#  (train)
# -------------
# epoch 462 || Epoch_D_Loss:0.0802 || Epoch_G_Loss:3.5658
# timer: 9.1402
# -----------------
# Epoch463/500
# -----------------
#  (train)
# -------------
# epoch 463 || Epoch_D_Loss:0.0603 || Epoch_G_Loss:3.6718
# timer: 9.1682
# -----------------
# Epoch464/500
# -----------------
#  (train)
# -------------
# epoch 464 || Epoch_D_Loss:0.0449 || Epoch_G_Loss:3.7431
# timer: 9.1567
# -----------------
# Epoch465/500
# -----------------
#  (train)
# -------------
# epoch 465 || Epoch_D_Loss:0.0492 || Epoch_G_Loss:3.8706
# timer: 9.2277
# -----------------
# Epoch466/500
# -----------------
#  (train)
# -------------
# epoch 466 || Epoch_D_Loss:0.0776 || Epoch_G_Loss:3.6000
# timer: 9.2300
# -----------------
# Epoch467/500
# -----------------
#  (train)
# -------------
# epoch 467 || Epoch_D_Loss:0.0490 || Epoch_G_Loss:3.6042
# timer: 9.2815
# -----------------
# Epoch468/500
# -----------------
#  (train)
# -------------
# epoch 468 || Epoch_D_Loss:0.0856 || Epoch_G_Loss:3.7484
# timer: 9.3554
# -----------------
# Epoch469/500
# -----------------
#  (train)
# -------------
# epoch 469 || Epoch_D_Loss:0.0515 || Epoch_G_Loss:3.9090
# timer: 9.2319
# -----------------
# Epoch470/500
# -----------------
#  (train)
# -------------
# epoch 470 || Epoch_D_Loss:0.0509 || Epoch_G_Loss:3.6364
# timer: 9.2708
# -----------------
# Epoch471/500
# -----------------
#  (train)
# -------------
# epoch 471 || Epoch_D_Loss:0.0521 || Epoch_G_Loss:4.0106
# timer: 9.2391
# -----------------
# Epoch472/500
# -----------------
#  (train)
# -------------
# epoch 472 || Epoch_D_Loss:0.0578 || Epoch_G_Loss:3.7613
# timer: 9.2911
# -----------------
# Epoch473/500
# -----------------
#  (train)
# -------------
# epoch 473 || Epoch_D_Loss:0.0828 || Epoch_G_Loss:3.5533
# timer: 9.2285
# -----------------
# Epoch474/500
# -----------------
#  (train)
# -------------
# epoch 474 || Epoch_D_Loss:0.0541 || Epoch_G_Loss:3.9471
# timer: 9.1681
# -----------------
# Epoch475/500
# -----------------
#  (train)
# -------------
# epoch 475 || Epoch_D_Loss:0.0649 || Epoch_G_Loss:3.8413
# timer: 9.2828
# -----------------
# Epoch476/500
# -----------------
#  (train)
# -------------
# epoch 476 || Epoch_D_Loss:0.0489 || Epoch_G_Loss:3.9329
# timer: 9.2412
# -----------------
# Epoch477/500
# -----------------
#  (train)
# -------------
# epoch 477 || Epoch_D_Loss:0.0619 || Epoch_G_Loss:3.8473
# timer: 9.1198
# -----------------
# Epoch478/500
# -----------------
#  (train)
# -------------
# epoch 478 || Epoch_D_Loss:0.0653 || Epoch_G_Loss:4.0002
# timer: 9.3964
# -----------------
# Epoch479/500
# -----------------
#  (train)
# -------------
# epoch 479 || Epoch_D_Loss:0.0517 || Epoch_G_Loss:3.8867
# timer: 9.1683
# -----------------
# Epoch480/500
# -----------------
#  (train)
# -------------
# epoch 480 || Epoch_D_Loss:0.0707 || Epoch_G_Loss:3.9642
# timer: 9.1854
# -----------------
# Epoch481/500
# -----------------
#  (train)
# -------------
# epoch 481 || Epoch_D_Loss:0.0636 || Epoch_G_Loss:3.9532
# timer: 9.3222
# -----------------
# Epoch482/500
# -----------------
#  (train)
# -------------
# epoch 482 || Epoch_D_Loss:0.0728 || Epoch_G_Loss:3.6680
# timer: 9.1593
# -----------------
# Epoch483/500
# -----------------
#  (train)
# -------------
# epoch 483 || Epoch_D_Loss:0.0426 || Epoch_G_Loss:3.6446
# timer: 9.2034
# -----------------
# Epoch484/500
# -----------------
#  (train)
# -------------
# epoch 484 || Epoch_D_Loss:0.0640 || Epoch_G_Loss:3.5977
# timer: 9.1811
# -----------------
# Epoch485/500
# -----------------
#  (train)
# -------------
# epoch 485 || Epoch_D_Loss:0.0492 || Epoch_G_Loss:3.8559
# timer: 9.2863
# -----------------
# Epoch486/500
# -----------------
#  (train)
# -------------
# epoch 486 || Epoch_D_Loss:0.0518 || Epoch_G_Loss:4.1048
# timer: 9.2111
# -----------------
# Epoch487/500
# -----------------
#  (train)
# -------------
# epoch 487 || Epoch_D_Loss:0.0388 || Epoch_G_Loss:3.9834
# timer: 9.2006
# -----------------
# Epoch488/500
# -----------------
#  (train)
# -------------
# epoch 488 || Epoch_D_Loss:0.0529 || Epoch_G_Loss:3.8608
# timer: 9.1443
# -----------------
# Epoch489/500
# -----------------
#  (train)
# -------------
# epoch 489 || Epoch_D_Loss:0.0640 || Epoch_G_Loss:3.9553
# timer: 9.2124
# -----------------
# Epoch490/500
# -----------------
#  (train)
# -------------
# epoch 490 || Epoch_D_Loss:0.0533 || Epoch_G_Loss:3.9274
# timer: 9.1495
# -----------------
# Epoch491/500
# -----------------
#  (train)
# -------------
# epoch 491 || Epoch_D_Loss:0.0563 || Epoch_G_Loss:3.7946
# timer: 9.0777
# -----------------
# Epoch492/500
# -----------------
#  (train)
# -------------
# epoch 492 || Epoch_D_Loss:0.0534 || Epoch_G_Loss:3.9715
# timer: 9.1421
# -----------------
# Epoch493/500
# -----------------
#  (train)
# -------------
# epoch 493 || Epoch_D_Loss:0.0436 || Epoch_G_Loss:3.9389
# timer: 9.1768
# -----------------
# Epoch494/500
# -----------------
#  (train)
# -------------
# epoch 494 || Epoch_D_Loss:0.0459 || Epoch_G_Loss:4.1910
# timer: 9.1216
# -----------------
# Epoch495/500
# -----------------
#  (train)
# -------------
# epoch 495 || Epoch_D_Loss:0.0621 || Epoch_G_Loss:3.9308
# timer: 9.1815
# -----------------
# Epoch496/500
# -----------------
#  (train)
# -------------
# epoch 496 || Epoch_D_Loss:0.1080 || Epoch_G_Loss:3.8316
# timer: 9.3051
# -----------------
# Epoch497/500
# -----------------
#  (train)
# -------------
# epoch 497 || Epoch_D_Loss:0.0652 || Epoch_G_Loss:3.8185
# timer: 9.1655
# -----------------
# Epoch498/500
# -----------------
#  (train)
# -------------
# epoch 498 || Epoch_D_Loss:0.0302 || Epoch_G_Loss:3.9939
# timer: 9.1431
# -----------------
# Epoch499/500
# -----------------
#  (train)
# -------------
# epoch 499 || Epoch_D_Loss:0.0424 || Epoch_G_Loss:4.0407
# timer: 9.1258

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

batch_size = 32
feature_dim = 100
fixed_z = torch.randn(batch_size, feature_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

batch_iterator = iter(train_dataloader)
images = next(batch_iterator)

fig = plt.figure(figsize=(15,6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    img = transforms.functional.to_pil_image(images[i])
    plt.imshow(img)

    plt.subplot(2, 5, 5+i+1)
    fake_img = transforms.functional.to_pil_image(fake_images[i])
    plt.imshow(fake_img)
    fake_img.save(f"./out/image_generated/64SAGAN{i+5}.png",quality=95)
